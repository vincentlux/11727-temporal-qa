# %%
import csv 
import json 
from collections import Counter
#import spacy
#nlp = spacy.load('en_core_web_sm', disable=['ner'])
from tqdm import tqdm
from spacy.matcher import Matcher
from spacy.tokens import Span 
import nltk
from nltk.corpus import stopwords
skip_words = set(stopwords.words('english'))
import stanza
nlp = stanza.Pipeline('en')
# Out:
# 2020-04-21 16:29:27 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | ner       | ontonotes |
# =========================
#
# 2020-04-21 16:29:27 INFO: Use device: gpu
# 2020-04-21 16:29:27 INFO: Loading: tokenize
# 2020-04-21 16:29:31 INFO: Loading: pos
# 2020-04-21 16:29:33 INFO: Loading: lemma
# 2020-04-21 16:29:33 INFO: Loading: depparse
# 2020-04-21 16:29:34 INFO: Loading: ner
# 2020-04-21 16:29:35 INFO: Done loading processors!

# %%
def read_data(file):
    data = []
    with open(file, 'r') as f:
        for line in f:
            sample = line.strip().split('\t')
            assert len(sample) == 5
            data.append(sample)
    return data

# %%
def read_garbage(file, lead='verb'):
    garbage = {}
    concept_len = Counter()
    with open(file, 'r') as f:
        reader = csv.reader(f, delimiter=',')
        for i, line in enumerate(reader):
            subj, verb, obj = line[0],line[1], line[2]
            if lead == 'verb':
                head1, head2, head3 = verb, subj, obj
            elif lead == 'subj': 
                head1, head2, head3 = subj, obj, verb
            else:
                head1, head2, head3 = obj, subj, verb
            if head1 not in garbage:
                garbage[head1] = {head2:{head3:[line[3]]}}
            elif head2 not in garbage[head1]:
                garbage[head1][head2] = {head3:[line[3]]}
            elif head3 not in garbage[head1][head2]:
                garbage[head1][head2][head3] = [line[3]]
            else:
                garbage[head1][head2][head3] += [line[3]]
        print (i)
    print (len(garbage))
    return garbage
garbage_verb = read_garbage('/home/kaixinm/kaixinm/Wikipedia/python-sutime/DURATION.csv')
garbage_subj = read_garbage('/home/kaixinm/kaixinm/Wikipedia/python-sutime/DURATION.csv', lead='subj')
garbage_obj = read_garbage('/home/kaixinm/kaixinm/Wikipedia/python-sutime/DURATION.csv', lead='obj')
# Out:
# 5411527
# 61921
# 5411527
# 300483
# 5411527
# 118900

# %%
print (garbage_verb['log'])
# Out:
# {'recipient': {'': ['20 hours'], 'hours': ['a week']}, '': {'': ['the next seven years', 'thousand hours', 'weeks', 'day', 'hours', 'day', 'minutes', 'minutes', 'century', 'days', 'hours', 'hours', 'hours', 'seven weeks', 'seven weeks', '125 hours', 'hours', '3,000 hours', 'hours', '5000 hours', '5000 hours', '12 weeks', 'seven weeks', 'weeks', 'year', 'minutes', 'two weeks', '1,000 hours', 'days', 'days', 'hours', 'thousands of hours', '1,045 hrs', '22 Minutes', 'more than 593 hours', 'weeks', 'the hours', 'hours', '300 hours', 'four hours', '120 hours', 'minutes', 'up to 20 hours', '150 hours', 'one month'], 'builder': ['25 years'], 'game': ['week'], 'valley': ['about 50 years'], 'Y': ['days'], 'hours': ['year', 'the next 30 days', '30 days'], 'accident': ['hours'], 'tear': ['1,000\xa0hours'], 'weeks': ['year'], 'total': ['4,398 hours'], 'majority': ['the minutes'], 'growth': ['the 2018 year'], 'round': ['year'], 'readings': ['a second'], 'more': ['year']}, 'candidate': {'minimum': ['20 days']}, 'Bass': {'': ['1943 minutes']}, 'who': {'': ['a day', '20 hours'], 'hours': ['a week']}, 'people': {'': ['day']}, 'those': {'': ['hours']}, 'volunteers': {'': ['200,000 hours']}, 'he': {'': ['minute', 'minutes', 'an hour']}, 'They': {'amount': ['hours', 'week']}, 'One': {'time': ['day']}, 'users': {'': ['five days', 'hours']}, 'user': {'': ['fifteen days', '30 days', 'days']}, 'she': {'': ['one hour']}, 'She': {'': ['minutes']}, 'students': {'': ['about 45,000 hours', '200,000 hours'], 'minimum': ['115 hours']}, 'RSO': {'': ['10 weeks']}, 'formula_': {'': ['seconds', 'seconds']}, 'Pilots': {'': ['hours'], 'hours': ['a year']}, 'Learners': {'': ['100 hours', '100 hours']}, 'PA': {'': ['hours']}, 'White': {'': ['hours'], 'hours': ['about 2,200 hours']}, 'many': {'cabins': ['the early days']}, 'they': {'': ['hours']}, 'teams': {'hundreds more': ['decades']}, 'Ends': {'': ['32 weeks']}, 'Callers': {'': ['10 minutes']}, 'it': {'': ['twenty years']}, 'Graduates': {'': ['more than 600 hours']}}

# %%
def check_role(label):
    print (label)
    if 'subj' in label or 'obj' in label:
        return True
    else:
        return False
def extract_info(content):
    doc = nlp(content)
    query = [[], [], []]
    all_words = doc.sentences[0].words
    root = [w for w in doc.sentences[0].words if w.deprel == 'root'][0]
    if content.startswith('it'):
        print (content)
        #print (all_words)
    if not root.xpos.startswith('VB'):
        #print (all_words)
        if root.xpos.startswith('JJ'):
            #query[1].append(root.text)
            for w in doc.sentences[0].words:
                if 'root' in w.deprel:
                    query[1].append(w.text)
                if 'subj' in w.deprel:
                    query[0].append(w.text)
                if 'nmod' in w.deprel:
                    query[2].append(w.text)
            #print (content)
        else:
        #elif root.xpos.startswith('NN'):
            #query[0].append(root.text)
            for w in doc.sentences[0].words:
                if 'root' in w.deprel:
                    query[0].append(w.text)
                if 'amod' in w.deprel and len(query[0]) != 0:
                    query[1].append(w.text)
                if 'nmod' in w.deprel and len(query[0]) != 0:
                    query[2].append(w.text)
            #print (content)
        #else:
        #    print (all_words)
        #if 'last' in content:
        #    query[1].append('last')
    else:
        for w in  doc.sentences[0].words:

            if w.head == 0:
                query[1].append(w.text)
            if (all_words[w.head-1].head == 0 and 'subj' in w.deprel):
                query[0].append(w.text)
            if (all_words[w.head-1].head == 0 and 'obj' in w.deprel):
                query[2].append(w.text)
    query = [' '.join(part) for part in query]
    #print (query)
    return query

def find_patterns(data):
    start = Counter()
    prev = ''
    for sample in data:
        if sample[-1] == 'Event Duration':
            if prev == sample[1]:
                continue
            prev = sample[1]
            question = nltk.word_tokenize(sample[1].lower())
            q_tags = nltk.pos_tag(question)
            if 'how' not in question:
                content = sample[1].lower()
            elif not q_tags[2][1].startswith('VB') and 'would' not in question:
                for i in range(3, len(q_tags)):
                    if q_tags[i][1].startswith('VB'):
                        break
                if len(question)>i+3 and question[i+1] == 'it' and (question[i+2] == 'take' or question[i+2] == 'taken'):
                    q_words = ' '.join(question[:i+3])
                    content = ' '.join(question[i+3:])
                else:
                    q_words = ' '.join(question[:i+1])
                    content = ' '.join(question[i+1:])
            else:
                if len(question)>5 and question[3] == 'it' and (question[4] == 'take' or question[4] == 'taken'):
                    q_words = ' '.join(question[:5])
                    content = ' '.join(question[5:])
                else:
                    q_words = ' '.join(question[:3])
                    content = ' '.join(question[3:])
            start[q_words] += 1
            if len(content) == 0:
                continue
            query = extract_info(content)
            level, results = search_in_garbage(query, garbage)
            if level == 2:
                subj_level, subj_results = search_in_garbage_subj(query, garbage_subj, garbage_obj)
                if subj_level == 2:
                    results += subj_results
            elif level == 1:
                subj_level, subj_results = search_in_garbage_subj(query, garbage_subj, garbage_obj)
                if subj_level == 2:
                    results = subj_results 
                    level = subj_level
                elif subj_level == 1:
                    results += subj_results
            elif level == 0:
                level, results = search_in_garbage_subj(query, garbage_subj, garbage_obj)
            print (query)
            print (level)
            print (results)
            break
    #print (start)

# %%
def search_in_garbage(query, garbage):
    if query[1] != '' and query[1] in garbage:
        if query[0] != '' and query[0] in garbage[query[1]]:
            if query[2] != '' and query[2] in garbage[query[1]][query[0]]:
                results = garbage[query[1]][query[0]][query[2]]      # all 3 words matched
                return 3, results   # how many words matched
            elif query[2] != '':   # there exists object but not matched 
                results = [vv for obj, v in garbage[query[1]][query[0]].items() for vv in v]  # stuff matched by verb and subj
                for subj, d in garbage[query[1]].items():  # search for all that could be matched by verb and obj
                    for obj, v in d.items():
                        if obj == query[2]:
                            results += v
                return 2, results     # all level 2 matched
            else:
                results = [vv for obj, v in garbage[query[1]][query[0]].items() for vv in v]  # only has verb and subj, already the best we can do
                return 2, results 
        elif query[2] != '':  # subj not matched and obj exist
            results = []
            for subj, d in garbage[query[1]].items():  # search for all that could be matched by verb and obj
                for obj, v in d.items():
                    if obj == query[2]:
                        results += v
            if len(results) > 0:
                return 2, results
            else:        # the best we can do is matching only with verb
                for subj, d in garbage[query[1]].items():
                    for obj, v in d.items():
                        results += v
                return 1, results
        else:   # the best we can do is matching only with verb
            results = []
            for subj, d in garbage[query[1]].items():
                for obj, v in d.items():
                    results += v
            return 1, results
    return 0, []

# %%
def search_in_garbage_subj(query, garbage, next_garbage):
    if query[0] != '' and query[0] in garbage:
        if query[2] != '' and query[2] in garbage[query[0]]:  # we search for subj and obj match
                results = [vv for obj, v in garbage[query[0]][query[2]].items() for vv in v]
                return 2, results 
        elif query[2] != '':  # obj not matched but exist
            results = []   # all matched with subj
            for obj, d in garbage[query[0]].items():
                for verb, v in d.items():
                    results += v
            results += search_in_garbage_obj(query, next_garbage)
            return 1, results
        else:   # the best we can do is matching only with subj
            results = []
            for obj, d in garbage[query[0]].items():
                for verb, v in d.items():
                    results += v
            return 1, results
    elif query[2] != '':
        results = []
        results += search_in_garbage_obj(query, next_garbage)
        return 1, results
    return 0, []
def search_in_garbage_obj(query, garbage):
    if query[2] != '' and query[2] in garbage:
        results = []
        for subj, d in garbage[query[2]].items():
            for verb, v in d.items():
                results += v
        return results
    return []

# %%
data = read_data('MCTACO/dataset/dev_3783.tsv')
#grounding_concepts([data[4]])
find_patterns(data)
# Out:
# ['minority', 'remained', '']
# 1
# ['seven years', 'from 1959 to 1974', 'four years', 'the next few years', 'the next two years', '10 weeks', 'nine weeks', 'five years', 'decades', 'from 1440 to 1823', '61\xa0weeks', '73\xa0weeks', '61\xa0weeks', 'the final week', 'century', 'a century', 'seven weeks', '20 weeks', 'sixteen weeks', 'six years', 'two years', '111 weeks', 'a decade', 'weeks', 'more than 24 years', '86 weeks', 'ten weeks', '1995-1996', '12 years', 'four weeks', 'several years', '50 years', 'six weeks', 'the next few centuries', 'the next 150 years', 'from 1925 to 1972', 'another ten weeks', 'eight weeks', '60 years', 'seven weeks', 'eight years', 'years', 'more than a decade', 'one year', 'the first 18 months', 'weeks', 'eighteen weeks', '1925-1926', 'several years', 'centuries', 'years', 'the next few years', 'twenty months', 'two years', 'sixteen years', '10 weeks', 'more than forty years', '65 weeks', 'several years', 'three-year', 'year', 'several days', 'four weeks', 'years', 'years', '25 years', 'a second', '1392 - 1910', 'one week', 'five years', 'two weeks', '19 weeks', 'two weeks', '30 years', 'a year', 'the next eleven years', '24 years', 'six months', 'several weeks', '31 years', 'two weeks', 'years', 'the next 25 years', '36 hours', 'seven years', '19 years', 'years', 'two years', 'five years', 'the second consecutive year', '23 years', 'years', 'a year', '72 weeks', 'centuries', 'six years', 'weeks', 'weeks', 'weeks', 'weeks', 'the next 13 months', '0.3 seconds', '13 weeks', 'ten weeks', 'three weeks', '17 weeks', 'several months', 'the next two years', 'from 1936 to 1967', 'four weeks', 'weeks', 'eight years', '24 years old', 'a year', 'six weeks', '45 weeks', 'weeks', '10 weeks', 'one week', 'years', '160 weeks', 'years', 'the 12 years', 'years', 'years', '33\xa0seconds', 'years', 'six weeks', '4\xa0minutes', 'two years', 'hundred years', 'eight weeks', 'years', 'another decade', 'more than fifteen years', 'four days', 'The 24 Hours', '150 years', 'four years', 'decades', 'months', 'centuries', 'twenty-two weeks', 'two years', 'years', '55 years', 'a week', 'more than three months', '28 years', 'the initial decade', '22 years', 'two weeks', 'ten weeks', 'two decades', 'several years', 'years', 'later years', 'a month', 'six years', 'eight days', 'an hour', 'hundred and thirty years', 'weeks', 'one week', 'eight years', 'Weeks', 'three weeks', 'years', 'two years', 'a year', '34 years', 'several centuries', '32 years', 'years', 'fifteen years', 'seven years', 'the next fifty years', 'years', 'a year', 'years', '1200 years', 'one day', 'the next three weeks', 'two months', 'years', 'the next fifty years', '8 weeks', 'six weeks', 'four years', 'centuries', 'years', '30 years', '57 years', 'more than a year', '6 weeks', '20 seconds', 'the next twenty years', 'weeks', 'eight centuries', 'four days', 'a few years', 'years', 'five years', '26 weeks', '15 years', '7 years', 'weeks', 'eight weeks', 'sixty years', '37 years', 'about ten years', 'years', 'a century', 'fourteen years', 'the following twenty-one years', 'from 1917 to 1919', 'several months', 'two months', 'weeks', 'weeks', 'a second', 'week', 'several years', 'a second', 'week', 'three-years', '21 weeks', 'several months', 'thirteen weeks', 'a year', 'two years', 'six weeks', 'six weeks', '13\xa0weeks', 'the next five years', '12 weeks', 'two weeks', 'four weeks', '19 weeks', 'six years', 'three years', 'seven weeks', 'nearly 20 years', '1 week', '7 weeks', 'seven weeks', 'years', 'from 1947 to 1957', 'a year', '75 years', 'decades', '24 hours', 'about 90 minutes', 'nine weeks', 'several years', '14,000 years', 'seven minutes', 'forty-two seconds', 'eight minutes', 'twenty-eight seconds', 'weeks', 'two weeks', 'centuries', 'several days', 'hours', 'two weeks', '33 years', '1942-1944', 'three years', '13 weeks', '20 weeks', 'months', 'two months', '25 years', 'an hour', '27 weeks', 'from 4 March to 2 September 2006', 'two weeks', '4 minutes', 'one day', 'More than a year', 'weeks' ...
